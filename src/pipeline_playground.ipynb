# %%
SparkContext
# Out:
# pyspark.context.SparkContext

# %%
# !pwd
# Out:
# /home/almalinux/eda1-coursework/src/merizo_pipeline

# %%
# !pip3 install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch==2.0.1+cpu
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.0.1%2Bcpu-cp39-cp39-linux_x86_64.whl (195.4 MB)
# Requirement already satisfied: einops in /home/almalinux/.local/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (0.8.0)
# Requirement already satisfied: matplotlib in /home/almalinux/.local/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (3.9.3)
# Requirement already satisfied: natsort in /home/almalinux/.local/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (8.4.0)
# Requirement already satisfied: networkx in /home/almalinux/.local/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: numpy<2.0 in /home/almalinux/.local/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: rotary_embedding_torch in /home/almalinux/.local/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.8.6)
# Requirement already satisfied: scipy in /home/almalinux/.local/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: setuptools in /home/almalinux/.local/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (75.6.0)
# Requirement already satisfied: faiss-cpu in /home/almalinux/.local/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.9.0.post1)
# Requirement already satisfied: fs in /home/almalinux/.local/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (2.4.16)
# Requirement already satisfied: filelock in /usr/lib/python3.9/site-packages (from torch==2.0.1+cpu->-r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: jinja2 in /home/almalinux/.local/lib/python3.9/site-packages (from torch==2.0.1+cpu->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: sympy in /home/almalinux/.local/lib/python3.9/site-packages (from torch==2.0.1+cpu->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: typing-extensions in /home/almalinux/.local/lib/python3.9/site-packages (from torch==2.0.1+cpu->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/almalinux/.local/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/almalinux/.local/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/almalinux/.local/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (4.55.2)
# Requirement already satisfied: pillow>=8 in /home/almalinux/.local/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/almalinux/.local/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/almalinux/.local/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (6.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/almalinux/.local/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: cycler>=0.10 in /home/almalinux/.local/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/almalinux/.local/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.7)
# Requirement already satisfied: six~=1.10 in /usr/lib/python3.9/site-packages (from fs->-r requirements.txt (line 11)) (1.15.0)
# Requirement already satisfied: appdirs~=1.4.3 in /home/almalinux/.local/lib/python3.9/site-packages (from fs->-r requirements.txt (line 11)) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /home/almalinux/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 3)) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/almalinux/.local/lib/python3.9/site-packages (from jinja2->torch==2.0.1+cpu->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/almalinux/.local/lib/python3.9/site-packages (from sympy->torch==2.0.1+cpu->-r requirements.txt (line 1)) (1.3.0)

# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
sc = spark.sparkContext
sc.setLogLevel("ERROR")

# %%
sc.master
# Out:
# 'local[4]'

# %%
os.getcwd()
# Out:
# '/home/almalinux/eda1-coursework/src/merizo_pipeline'

# %%
input_dir = "/UP000000625_83333_ECOLI_v4/"

# %%
file_rdd = sc.wholeTextFiles(input_dir + "*.pdb")
file_paths_rdd = file_rdd.map(lambda x: (x[0], os.path.basename(x[0])))

# %%
from pyspark import SparkFiles
local_file_path = SparkFiles.get(input_dir + "/AF-Q46839-F1-model_v4.pdb")
local_file_path
# Out:
# '/UP000000625_83333_ECOLI_v4/AF-Q46839-F1-model_v4.pdb'

# %%
# !ls
# Out:
# AF-P0A6S3-F1-model_v4.pdb_search.tsv   AF-Q47319-F1-model_v4.pdb_segment.tsv
# AF-P0A6S3-F1-model_v4.pdb_segment.tsv  merizo_pipeline
# AF-P28246-F1-model_v4.pdb_segment.tsv  pipeline_job.py
# AF-P76097-F1-model_v4.pdb.parsed       pipeline_playground.ipynb
# AF-P76097-F1-model_v4.pdb_search.tsv   remove_requirements.txt
# AF-P76097-F1-model_v4.pdb_segment.tsv  requirements.txt
# AF-P77672-F1-model_v4.pdb.parsed       results_parser.py
# AF-P77672-F1-model_v4.pdb_search.tsv   setup.py
# AF-P77672-F1-model_v4.pdb_segment.tsv  test.bin
# AF-Q47319-F1-model_v4.pdb.parsed       test_requirements.txt
# AF-Q47319-F1-model_v4.pdb_search.tsv   tmp-6c3f26804cda43c89b65f248cc62cd16

# %%
from subprocess import Popen, PIPE
from tempfile import NamedTemporaryFile
import os

# %%
input_dir = "/UP000000625_83333_ECOLI_v4/"
# input_dir = "/"
# Failed example : AF-P0DSE5-F1-model_v4.pdb
# Success example: AF-P75975-F1-model_v4.pdb
file_rdd = sc.binaryFiles(input_dir + "*.pdb")
file_rdd = file_rdd.sample(withReplacement=False, fraction=0.005)
file_content_rdd = file_rdd.map(lambda x: (os.path.basename(x[0]), x[1]))

# %%
def delete_local_file(file_path):
    try:
        os.remove(file_path)
        print(f"{file_path} local file has been deleted.")
    except FileNotFoundError:
        print(f"{file_path} does not exist.")
    except PermissionError:
        print(f"Permission denied to delete {file_path}.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
def upload_file_to_hdfs(local_file_path, hdfs_file_path):
    hdfs_put_cmd = ['/home/almalinux/hadoop-3.4.0/bin/hdfs', 'dfs', '-put', local_file_path, hdfs_file_path]
    print(f'STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: {" ".join(hdfs_put_cmd)}')
    p = Popen(hdfs_put_cmd, stdin=PIPE,stdout=PIPE, stderr=PIPE)
    out, err = p.communicate()
    # Decode the byte output to string
    print("Output:")
    print(out.decode("utf-8"))  # Decode and print the standard output
    
    if err:
        print("Error:")
        print(err.decode("utf-8"))  # Decode and print the standard

# %%
def run_parser(input_file):
    """
    Run the results_parser.py over the hhr file to produce the output summary
    """
    search_file = input_file+"_search.tsv"
    print("search_file: ", search_file)
    cmd = ['python3', './results_parser.py', search_file]
    print(f'STEP 2: RUNNING PARSER: {" ".join(cmd)}')
    p = Popen(cmd, stdin=PIPE,stdout=PIPE, stderr=PIPE)
    out, err = p.communicate()
    # Decode the byte output to string
    print("Output:")
    print(out.decode("utf-8"))  # Decode and print the standard output
        
    if err:
        print("Error:")
        print(err.decode("utf-8"))  # Decode and print the standard error

# %%
def run_merizo_search(file_name, file_content):
    print(f"File Name: {file_name}")
    # Create a temporary file to hold the content
    with NamedTemporaryFile(delete=True, mode='wb') as temp_file:
        temp_file.write(file_content)
        temp_file_path = temp_file.name
        cmd = ['python3',
           '/home/almalinux/merizo_search/merizo_search/merizo.py',
           'easy-search',
           temp_file_path,
           '/home/almalinux/data/cath-4.3-foldclassdb',
           file_name,
           'tmp',
           '--iterate',
           '--output_headers',
           '-d',
           'cpu',
           '--threads',
           '2'
          ]
        print(f'STEP 1: RUNNING MERIZO: {" ".join(cmd)}')
        p = Popen(cmd, stdin=PIPE,stdout=PIPE, stderr=PIPE)
        out, err = p.communicate()
        # Decode the byte output to string
        print("Output:")
        print(out.decode("utf-8"))  # Decode and print the standard output
        
        if err:
            print("Error:")
            print(err.decode("utf-8"))  # Decode and print the standard

# %%
def upload_analysis_outputs_to_hdfs(file_name):
    # upload anaylsis output files to hdfs and clean local files
    local_files_paths = [ file_name + '_segment.tsv', file_name + '_search.tsv', file_name + '.parsed']
    hdfs_file_path = '/analysis_outputs/'
    for local_file_path in local_files_paths:
        upload_file_to_hdfs(local_file_path, hdfs_file_path)
        delete_local_file(local_file_path)

# %%
def combine_parsed_dict_and_mean(analysis_output1, analysis_output2):
    cath_counts_dict1, mean_plddt1 = analysis_output1
    cath_counts_dict2, mean_plddt2 = analysis_output2

    for key in cath_counts_dict2:
        if key in cath_counts_dict1:
            cath_counts_dict1[key] +=cath_counts_dict2[key]
        else:
            cath_counts_dict1[key] = cath_counts_dict2[key]

    mean_plddt = (mean_plddt1 + mean_plddt2) / 2.0

    return cath_counts_dict1, mean_plddt

analysis_output1 = ({'3.40.710.10': 1}, 98.4244)
analysis_output2 = ({'3.40.710.10': 3, '2.30.810.20': 2}, 88.4244)

combine_parsed_dict_and_mean(analysis_output1, analysis_output2)
# Out:
# ({'3.40.710.10': 4, '2.30.810.20': 2}, 93.4244)

# %%
def combine_parsed_dict(cath_counts_dict1, cath_counts_dict2):

    for key in cath_counts_dict2:
        if key in cath_counts_dict1:
            cath_counts_dict1[key] +=cath_counts_dict2[key]
        else:
            cath_counts_dict1[key] = cath_counts_dict2[key]

    return cath_counts_dict1

cath_counts_dict1 = {'3.40.710.10': 1}
cath_counts_dict2 = {'3.40.710.10': 3, '2.30.810.20': 2}

combine_parsed_dict(cath_counts_dict1, cath_counts_dict2)
# Out:
# {'3.40.710.10': 4, '2.30.810.20': 2}

# %%
import os 

def read_parsed_file(file_name):
    """
    Reads a .parsed file and extracts:
    1. A dictionary with 'cath_id' as keys and their counts as values.
    2. The mean pLDDT value.
    
    Args:
        file_path (str): Path to the .parsed file.
        
    Returns:
        tuple: (dict of cath_id counts, mean pLDDT value)
    """
    cath_counts = {}
    mean_plddt = 0

    file_path = file_name + '.parsed'

    if not os.path.exists(file_path):
        return mean_plddt, cath_counts
    
    with open(file_path, 'r') as file:
        lines = file.readlines()
        
        # Extract mean pLDDT from the header
        if len(lines) < 1:
            return cath_counts, mean_plddt

        first_line = lines[0]
        if "mean plddt:" in first_line:
            mean_plddt = float(first_line.split("mean plddt:")[1].strip())
        
        # Skip the header and process the data rows
        for line in lines[2:]:  # Assuming data rows start from the 3rd line
            if not line.strip():
                continue # Ignore empty lines
            cath_id, count = line.strip().split(',')
            cath_counts[cath_id] = int(count)
    
    return mean_plddt, cath_counts

# # Apply the function to the uploaded file
# file_name = "AF-P00811-F1-model_v4.pdb"
# mean_plddt, cath_counts = read_parsed_file(file_name)
# mean_plddt, cath_counts

# %%
def pipeline(file_tuple):
    file_name, file_content = file_tuple
    # STEP 1
    run_merizo_search(file_name, file_content)
    # STEP 2
    run_parser(file_name)
    # STEP 3
    mean_plddt, cath_counts_dict = read_parsed_file(file_name)
    # STEP 4
    upload_analysis_outputs_to_hdfs(file_name)
    return mean_plddt, cath_counts_dict

# %%
pipeline_rdd = file_content_rdd.map(pipeline)

# %%
results_rdd = pipeline_rdd.collect()

# %%
from pyspark.sql.types import StructType, StructField, FloatType, StringType, MapType, IntegerType

schema = StructType([
    StructField("mean_plddt", FloatType(), False),
    StructField("cath_counts_dict", MapType(StringType(), IntegerType()), False)
])
df = spark.createDataFrame(results_rdd, schema)
df.show()
# Out:
# +----------+--------------------+
# |mean_plddt|    cath_counts_dict|
# +----------+--------------------+
# |   95.1058|{6.10.140.1350 ->...|
# |   95.7457|  {3.40.50.620 -> 1}|
# |   97.7731|{3.40.50.720 -> 1...|
# |  98.40875|{3.40.50.1970 -> ...|
# |       0.0|                  {}|
# |   90.7456|{1.10.287.1060 ->...|
# |   97.2253|{3.90.25.10 -> 1,...|
# |       0.0|                  {}|
# |   93.1894|  {3.40.50.300 -> 1}|
# |       0.0|                  {}|
# |  93.13824|{2.30.30.280 -> 1...|
# |   97.6179|{3.30.360.20 -> 1...|
# |   93.2427|{UNASSIGNED -> 1,...|
# |       0.0|                  {}|
# |   96.0342|   {3.40.47.10 -> 2}|
# |   92.0031|  {1.20.950.20 -> 1}|
# |   93.2138|    {1.10.8.50 -> 1}|
# +----------+--------------------+

# %%
import math
from collections import Counter
import time

# Define the zero value for the accumulator: (float_sum, float_sum_of_squares, float_count, combined_dict)
zero_value = (0.0, 0.0, 0, {})

# Function to combine a single record with the accumulator
def seq_op(accum, value):
    float_sum, float_sum_of_squares, float_count, combined_dict = accum
    new_float, new_dict = value
    return (
        float_sum + new_float,
        float_sum_of_squares + new_float ** 2,
        float_count + 1,
        dict(Counter(combined_dict) + Counter(new_dict)),
    )

# Function to merge two accumulators
def comb_op(accum1, accum2):
    float_sum1, float_sum_of_squares1, float_count1, dict1 = accum1
    float_sum2, float_sum_of_squares2, float_count2, dict2 = accum2
    return (
        float_sum1 + float_sum2,
        float_sum_of_squares1 + float_sum_of_squares2,
        float_count1 + float_count2,
        dict(Counter(dict1) + Counter(dict2)),
    )

# Use aggregate to compute the result
start_time = time.time()
result = pipeline_rdd.aggregate(zero_value, seq_op, comb_op)

# Extract results
float_sum, float_sum_of_squares, float_count, combined_dict = result
mean = float_sum / float_count

# std_dev = math.sqrt(float_sum_of_squares / (float_count - mean) ** 2)
# sample_variance = (float_sum_of_squares - (float_sum ** 2) / float_count) / (float_count - 1)
# sample_std_dev = math.sqrt(sample_variance) if float_count > 1 else 0.0
population_variance = (float_sum_of_squares - (float_sum ** 2) / float_count) / float_count
population_std_dev = math.sqrt(population_variance)

end_time = time.time()
total_time = end_time - start_time
print(f"Done with the pipeline in {total_time:.2f} seconds")  

# Final results
print("Combined Dictionary:", combined_dict)
print("Mean of Float Values:", mean)
print("Standard Deviation of Float Values:", population_std)
# Out:
# File Name: AF-P25714-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpwg5vy85r /home/almalinux/data/cath-4.3-foldclassdb AF-P25714-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# File Name: AF-P77409-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmptljtctku /home/almalinux/data/cath-4.3-foldclassdb AF-P77409-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# File Name: AF-P05719-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp8epzrgs5 /home/almalinux/data/cath-4.3-foldclassdb AF-P05719-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 18:56:29,449 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmptljtctku /home/almalinux/data/cath-4.3-foldclassdb AF-P77409-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:56:41,509 | INFO | Finished easy-search in 12.060 seconds.
#
# search_file:  AF-P77409-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P77409-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77409-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77409-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P77409-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77409-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77409-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P77409-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77409-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 18:56:31,657 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp8epzrgs5 /home/almalinux/data/cath-4.3-foldclassdb AF-P05719-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:56:48,570 | INFO | Finished easy-search in 16.912 seconds.
#
# search_file:  AF-P05719-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P05719-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P05719-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77409-F1-model_v4.pdb.parsed': File exists
#
# AF-P77409-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P77509-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpxjgnhv9w /home/almalinux/data/cath-4.3-foldclassdb AF-P77509-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P05719-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P05719-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P05719-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P05719-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P05719-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P05719-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P05719-F1-model_v4.pdb.parsed': File exists
#
# AF-P05719-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# 2024-12-25 18:56:29,671 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpwg5vy85r /home/almalinux/data/cath-4.3-foldclassdb AF-P25714-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:56:56,586 | INFO | Finished easy-search in 26.914 seconds.
#
# search_file:  AF-P25714-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P25714-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25714-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# File Name: AF-P0A6E4-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmppwgk1tm9 /home/almalinux/data/cath-4.3-foldclassdb AF-P0A6E4-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25714-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P25714-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25714-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25714-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P25714-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25714-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25714-F1-model_v4.pdb.parsed': File exists
#
# AF-P25714-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P25745-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp4myuymz1 /home/almalinux/data/cath-4.3-foldclassdb AF-P25745-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 18:56:53,892 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpxjgnhv9w /home/almalinux/data/cath-4.3-foldclassdb AF-P77509-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:57:17,115 | INFO | Finished easy-search in 23.223 seconds.
#
# search_file:  AF-P77509-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P77509-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77509-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77509-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P77509-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77509-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77509-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P77509-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77509-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 18:57:02,693 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmppwgk1tm9 /home/almalinux/data/cath-4.3-foldclassdb AF-P0A6E4-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:57:23,609 | INFO | Finished easy-search in 20.916 seconds.
#
# search_file:  AF-P0A6E4-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0A6E4-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A6E4-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77509-F1-model_v4.pdb.parsed': File exists
#
# AF-P77509-F1-model_v4.pdb.parsed local file has been deleted.
# Output:5:>                                                          (0 + 3) / 7]
#
# Error:
# 2024-12-25 18:57:08,652 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp4myuymz1 /home/almalinux/data/cath-4.3-foldclassdb AF-P25745-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:57:25,342 | INFO | Finished easy-search in 16.689 seconds.
#
# search_file:  AF-P25745-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P25745-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25745-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A6E4-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0A6E4-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A6E4-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25745-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P25745-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25745-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A6E4-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0A6E4-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A6E4-F1-model_v4.pdb.parsed /analysis_outputs/
# File Name: AF-P0AFQ2-F1-model_v4.pdb                                (1 + 4) / 7]
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp29qa012a /home/almalinux/data/cath-4.3-foldclassdb AF-P0AFQ2-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# File Name: AF-P0A9Q9-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpqwgcaxkw /home/almalinux/data/cath-4.3-foldclassdb AF-P0A9Q9-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25745-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P25745-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25745-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A6E4-F1-model_v4.pdb.parsed': File exists
#
# AF-P0A6E4-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25745-F1-model_v4.pdb.parsed': File exists
#
# AF-P25745-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P46849-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpk6ooheh7 /home/almalinux/data/cath-4.3-foldclassdb AF-P46849-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# File Name: AF-P75992-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp0cpkm69f /home/almalinux/data/cath-4.3-foldclassdb AF-P75992-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 18:57:34,128 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpqwgcaxkw /home/almalinux/data/cath-4.3-foldclassdb AF-P0A9Q9-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:57:48,512 | INFO | Finished easy-search in 14.383 seconds.
#
# search_file:  AF-P0A9Q9-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0A9Q9-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9Q9-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 18:57:32,472 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp29qa012a /home/almalinux/data/cath-4.3-foldclassdb AF-P0AFQ2-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:57:48,969 | INFO | Finished easy-search in 16.497 seconds.
#
# search_file:  AF-P0AFQ2-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0AFQ2-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AFQ2-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9Q9-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0A9Q9-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9Q9-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AFQ2-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0AFQ2-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AFQ2-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9Q9-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0A9Q9-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9Q9-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AFQ2-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0AFQ2-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AFQ2-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9Q9-F1-model_v4.pdb.parsed': File exists
#
# AF-P0A9Q9-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P0A9S1-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp0u_cioz2 /home/almalinux/data/cath-4.3-foldclassdb AF-P0A9S1-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AFQ2-F1-model_v4.pdb.parsed': File exists
#
# AF-P0AFQ2-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# 2024-12-25 18:57:50,507 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp0cpkm69f /home/almalinux/data/cath-4.3-foldclassdb AF-P75992-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:58:01,890 | INFO | Finished easy-search in 11.383 seconds.
#
# search_file:  AF-P75992-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P75992-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P75992-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# File Name: AF-P16690-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpzt_4xd5i /home/almalinux/data/cath-4.3-foldclassdb AF-P16690-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P75992-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P75992-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P75992-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 18:57:47,285 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpk6ooheh7 /home/almalinux/data/cath-4.3-foldclassdb AF-P46849-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:58:05,788 | INFO | Finished easy-search in 18.503 seconds.
#
# search_file:  AF-P46849-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P46849-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46849-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P75992-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P75992-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P75992-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46849-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P46849-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46849-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P75992-F1-model_v4.pdb.parsed': File exists
#
# AF-P75992-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46849-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P46849-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46849-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46849-F1-model_v4.pdb.parsed': File exists
#
# AF-P46849-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P46850-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpg1xx_gbu /home/almalinux/data/cath-4.3-foldclassdb AF-P46850-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# File Name: AF-P76503-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpdvd3rmle /home/almalinux/data/cath-4.3-foldclassdb AF-P76503-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 18:58:01,866 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp0u_cioz2 /home/almalinux/data/cath-4.3-foldclassdb AF-P0A9S1-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:58:22,523 | INFO | Finished easy-search in 20.657 seconds.
#
# search_file:  AF-P0A9S1-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0A9S1-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9S1-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9S1-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0A9S1-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9S1-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 18:58:09,851 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpzt_4xd5i /home/almalinux/data/cath-4.3-foldclassdb AF-P16690-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:58:26,439 | INFO | Finished easy-search in 16.587 seconds.
#
# search_file:  AF-P16690-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P16690-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P16690-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9S1-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0A9S1-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9S1-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P16690-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P16690-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P16690-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9S1-F1-model_v4.pdb.parsed': File exists
#
# AF-P0A9S1-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P0AA60-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpa3to8ihs /home/almalinux/data/cath-4.3-foldclassdb AF-P0AA60-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P16690-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P16690-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P16690-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P16690-F1-model_v4.pdb.parsed': File exists
#
# AF-P16690-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# 2024-12-25 18:58:19,449 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpg1xx_gbu /home/almalinux/data/cath-4.3-foldclassdb AF-P46850-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:58:45,590 | INFO | Finished easy-search in 26.141 seconds.
#
# search_file:  AF-P46850-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P46850-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46850-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 18:58:19,498 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpdvd3rmle /home/almalinux/data/cath-4.3-foldclassdb AF-P76503-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:58:45,957 | INFO | Finished easy-search in 26.459 seconds.
#
# search_file:  AF-P76503-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P76503-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P76503-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 18:58:37,572 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpa3to8ihs /home/almalinux/data/cath-4.3-foldclassdb AF-P0AA60-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:58:46,540 | INFO | Finished easy-search in 8.968 seconds.
#
# search_file:  AF-P0AA60-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0AA60-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AA60-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46850-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P46850-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46850-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P76503-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P76503-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P76503-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AA60-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0AA60-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AA60-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46850-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P46850-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46850-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P76503-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P76503-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P76503-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AA60-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0AA60-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AA60-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46850-F1-model_v4.pdb.parsed': File exists
#
# AF-P46850-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P76503-F1-model_v4.pdb.parsed': File exists
#
# AF-P76503-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AA60-F1-model_v4.pdb.parsed': File exists
#
# AF-P0AA60-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P0ABA6-F1-model_v4.pdb===============>                (5 + 2) / 7]
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp5r7b9n22 /home/almalinux/data/cath-4.3-foldclassdb AF-P0ABA6-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 18:58:58,841 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp5r7b9n22 /home/almalinux/data/cath-4.3-foldclassdb AF-P0ABA6-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:59:07,405 | INFO | Finished easy-search in 8.564 seconds.
#
# search_file:  AF-P0ABA6-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0ABA6-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0ABA6-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0ABA6-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0ABA6-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0ABA6-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0ABA6-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0ABA6-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0ABA6-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0ABA6-F1-model_v4.pdb.parsed': File exists
#
# AF-P0ABA6-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P0AC88-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpb_bkfe5k /home/almalinux/data/cath-4.3-foldclassdb AF-P0AC88-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 18:59:17,290 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpb_bkfe5k /home/almalinux/data/cath-4.3-foldclassdb AF-P0AC88-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 18:59:27,422 | INFO | Finished easy-search in 10.131 seconds.
#
# search_file:  AF-P0AC88-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0AC88-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AC88-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AC88-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0AC88-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AC88-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AC88-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0AC88-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AC88-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AC88-F1-model_v4.pdb.parsed': File exists
#
# AF-P0AC88-F1-model_v4.pdb.parsed local file has been deleted.
# Done with the pipeline in 195.10 seconds
# Combined Dictionary: {'3.90.220.20': 2, '6.10.140.1350': 1, '3.40.50.620': 2, '3.40.50.720': 2, '3.30.360.10': 1, '3.40.50.1970': 1, '1.20.1090.10': 1, '1.10.287.1060': 1, '3.40.1380.10': 1, '3.90.25.10': 1, '3.40.50.300': 1, '2.30.30.280': 1, '2.40.30.10': 1, '3.30.110.140': 1, '3.30.360.20': 1, '3.30.70.1560': 1, 'UNASSIGNED': 1, '3.40.47.10': 2, '1.20.950.20': 1, '1.10.8.50': 1}
# Mean of Float Values: 72.55550490196077
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 57
#      55 print("Combined Dictionary:", combined_dict)
#      56 print("Mean of Float Values:", mean)
# ---> 57 print("Standard Deviation of Float Values:", sample_std_dev)
#
# NameError: name 'sample_std_dev' is not defined

# %%
# Final results
print("Combined Dictionary:", combined_dict)
print("Mean of Float Values:", mean)
print("Standard Deviation of Float Values:", population_std_dev)
# Out:
# Combined Dictionary: {'3.90.220.20': 2, '6.10.140.1350': 1, '3.40.50.620': 2, '3.40.50.720': 2, '3.30.360.10': 1, '3.40.50.1970': 1, '1.20.1090.10': 1, '1.10.287.1060': 1, '3.40.1380.10': 1, '3.90.25.10': 1, '3.40.50.300': 1, '2.30.30.280': 1, '2.40.30.10': 1, '3.30.110.140': 1, '3.30.360.20': 1, '3.30.70.1560': 1, 'UNASSIGNED': 1, '3.40.47.10': 2, '1.20.950.20': 1, '1.10.8.50': 1}
# Mean of Float Values: 72.55550490196077
# Standard Deviation of Float Values: 40.29962422764759

# %%
# Convert results to DataFrames
# 1. Statistics DataFrame
stats_df = spark.createDataFrame(
    [("human", mean, population_std_dev), ("ecoli", mean, population_std_dev)],
    schema=StructType([
        StructField("organism", StringType(), True),
        StructField("mean plddt", FloatType(), True),
        StructField("plddt std", FloatType(), True),
    ])
).coalesce(1)

stats_df.show()

# 2. Dictionary DataFrame
dict_df = spark.createDataFrame(
    [(key, value) for key, value in combined_dict.items()],
    schema=StructType([
        StructField("cath_code", StringType(), True),
        StructField("count", IntegerType(), True),
    ])
).coalesce(1)

dict_df.show()
# Out:
# +--------+----------+---------+
# |organism|mean plddt|plddt std|
# +--------+----------+---------+
# |   human| 72.555504|40.299625|
# |   ecoli| 72.555504|40.299625|
# +--------+----------+---------+
#
# +-------------+-----+
# |    cath_code|count|
# +-------------+-----+
# |  3.90.220.20|    2|
# |6.10.140.1350|    1|
# |  3.40.50.620|    2|
# |  3.40.50.720|    2|
# |  3.30.360.10|    1|
# | 3.40.50.1970|    1|
# | 1.20.1090.10|    1|
# |1.10.287.1060|    1|
# | 3.40.1380.10|    1|
# |   3.90.25.10|    1|
# |  3.40.50.300|    1|
# |  2.30.30.280|    1|
# |   2.40.30.10|    1|
# | 3.30.110.140|    1|
# |  3.30.360.20|    1|
# | 3.30.70.1560|    1|
# |   UNASSIGNED|    1|
# |   3.40.47.10|    2|
# |  1.20.950.20|    1|
# |    1.10.8.50|    1|
# +-------------+-----+

# %%
# Write DataFrames to HDFS as CSV
stats_df.write.option("header","true").mode("overwrite").csv("/summary_outputs/pIDDT_means")
dict_df.write.option("header","true").mode("overwrite").csv("/summary_outputs/ecoli_cath_summary")

# %%
def write_df_to_hdfs_csv(df, hdfs_path, csv_file_name):
    print(f'WRITING ANALYSIS SUMMARY OUTPUT {csv_file_name} TO HDFS...')
    write_path = hdfs_path + csv_file_name
    df.write.option("header","true").mode("overwrite").csv(write_path)
    hdfs_mv_cmd = ['hdfs', 'dfs', '-mv', write_path + '/part-00000-*.csv', write_path + '.csv']
    p = Popen(hdfs_mv_cmd, stdin=PIPE,stdout=PIPE, stderr=PIPE)
    out, err = p.communicate()
    # Decode the byte output to string
    print("Output:")
    print(out.decode("utf-8"))  # Decode and print the standard output
    
    if err:
        print("Error:")
        print(err.decode("utf-8"))  # Decode and print the standard

# %%
write_df_to_hdfs_csv(stats_df, "/summary_outputs/", "pIDDT_means")
write_df_to_hdfs_csv(dict_df, "/summary_outputs/", "ecoli_cath_summary")
# Out:
# WRITING ANALYSIS SUMMARY OUTPUT pIDDT_means TO HDFS...
# Output:
#
# WRITING ANALYSIS SUMMARY OUTPUT ecoli_cath_summary TO HDFS...
# Output:

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, FloatType, StringType, MapType, IntegerType

def process_with_dataframes(rdd):
    """
    Convert RDD of (float, dict) to DataFrame and calculate statistics
    
    Args:
        rdd: RDD containing tuples of (mean_plddt, cath_counts_dict)
    Returns:
        Tuple of (stats_dict, combined_counts_dict)
    """
    # Define schema for our data
    schema = StructType([
        StructField("mean_plddt", FloatType(), False),
        StructField("cath_counts_dict", MapType(StringType(), IntegerType()), False)
    ])
    
    # Convert RDD to DataFrame
    df = spark.createDataFrame(rdd, schema)
    df.show()
    
    # Calculate statistics for float values
    stats_df = df.select(
        F.mean("mean_plddt").alias("mean"),
        F.stddev_pop("mean_plddt").alias("std_dev")
    )
    stats_df.show()
    
    # Combine dictionaries using explode and aggregation
    counts_df = df.select(
        F.explode("cath_counts_dict").alias("id", "count")
    ).groupBy(
        "id"
    ).agg(
        F.sum("count").alias("total_count")
    )

    counts_df.show()
    
    # # Convert results to Python dictionaries
    # statistics = {
    #     "mean": stats_df["mean"],
    #     "std_dev": stats_df["std_dev"] if stats_df["std_dev"] is not None else 0.0
    # }
    
    # combined_counts = dict(counts_df.collect())
    
    return stats_df, counts_df

# Example usage:
"""
# Assuming your map function returns (mean_plddt, cath_counts_dict)
mapped_rdd = rdd.map(your_map_function)
stats, counts = process_with_dataframes(mapped_rdd)

print(f"Mean: {stats['mean']}")
print(f"Standard Deviation: {stats['std_dev']}")
print("Combined counts:", counts)
"""
# Out:
# '\n# Assuming your map function returns (mean_plddt, cath_counts_dict)\nmapped_rdd = rdd.map(your_map_function)\nstats, counts = process_with_dataframes(mapped_rdd)\n\nprint(f"Mean: {stats[\'mean\']}")\nprint(f"Standard Deviation: {stats[\'std_dev\']}")\nprint("Combined counts:", counts)\n'

# %%
start_time = time.time()
results_rdd = pipeline_rdd.collect()
stats, combined_counts = process_with_dataframes(results_rdd)
end_time = time.time()
total_time = end_time - start_time
print(f"Done with the pipeline using collect in {total_time:.2f} seconds")
stats, combined_counts
# Out:
# File Name: AF-P25714-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpcmjlqvta /home/almalinux/data/cath-4.3-foldclassdb AF-P25714-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# File Name: AF-P77409-F1-model_v4.pdb                                (0 + 3) / 7]
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpxjvdqft6 /home/almalinux/data/cath-4.3-foldclassdb AF-P77409-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# File Name: AF-P05719-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpg0v_6_6p /home/almalinux/data/cath-4.3-foldclassdb AF-P05719-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 19:03:54,816 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpxjvdqft6 /home/almalinux/data/cath-4.3-foldclassdb AF-P77409-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:04:05,732 | INFO | Finished easy-search in 10.916 seconds.
#
# search_file:  AF-P77409-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P77409-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77409-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77409-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P77409-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77409-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77409-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P77409-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77409-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77409-F1-model_v4.pdb.parsed': File exists
#
# AF-P77409-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P77509-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpi69j61tb /home/almalinux/data/cath-4.3-foldclassdb AF-P77509-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 19:03:56,732 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpg0v_6_6p /home/almalinux/data/cath-4.3-foldclassdb AF-P05719-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:04:17,395 | INFO | Finished easy-search in 20.663 seconds.
#
# search_file:  AF-P05719-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P05719-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P05719-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 19:03:54,400 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpcmjlqvta /home/almalinux/data/cath-4.3-foldclassdb AF-P25714-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:04:18,884 | INFO | Finished easy-search in 24.483 seconds.
#
# search_file:  AF-P25714-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P25714-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25714-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P05719-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P05719-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P05719-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25714-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P25714-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25714-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P05719-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P05719-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P05719-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25714-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P25714-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25714-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P05719-F1-model_v4.pdb.parsed': File exists
#
# AF-P05719-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25714-F1-model_v4.pdb.parsed': File exists
#
# AF-P25714-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P25745-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpox5t64gf /home/almalinux/data/cath-4.3-foldclassdb AF-P25745-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# File Name: AF-P0A6E4-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp75w1am8d /home/almalinux/data/cath-4.3-foldclassdb AF-P0A6E4-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 19:04:17,590 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpi69j61tb /home/almalinux/data/cath-4.3-foldclassdb AF-P77509-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:04:39,129 | INFO | Finished easy-search in 21.539 seconds.
#
# search_file:  AF-P77509-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P77509-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77509-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77509-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P77509-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77509-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77509-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P77509-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P77509-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 19:04:30,783 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpox5t64gf /home/almalinux/data/cath-4.3-foldclassdb AF-P25745-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:04:45,417 | INFO | Finished easy-search in 14.633 seconds.
#
# search_file:  AF-P25745-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P25745-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25745-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P77509-F1-model_v4.pdb.parsed': File exists
#
# AF-P77509-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25745-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P25745-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25745-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 19:04:31,152 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp75w1am8d /home/almalinux/data/cath-4.3-foldclassdb AF-P0A6E4-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:04:50,054 | INFO | Finished easy-search in 18.901 seconds.
#
# search_file:  AF-P0A6E4-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0A6E4-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A6E4-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25745-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P25745-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P25745-F1-model_v4.pdb.parsed /analysis_outputs/
# File Name: AF-P0AFQ2-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpjhpcqd0k /home/almalinux/data/cath-4.3-foldclassdb AF-P0AFQ2-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# File Name: AF-P0A9Q9-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpe5vw8txp /home/almalinux/data/cath-4.3-foldclassdb AF-P0A9Q9-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A6E4-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0A6E4-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A6E4-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P25745-F1-model_v4.pdb.parsed': File exists
#
# AF-P25745-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A6E4-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0A6E4-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A6E4-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A6E4-F1-model_v4.pdb.parsed': File exists
#
# AF-P0A6E4-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P75992-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpdkxoy2g3 /home/almalinux/data/cath-4.3-foldclassdb AF-P75992-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# File Name: AF-P46849-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpubtjc1d2 /home/almalinux/data/cath-4.3-foldclassdb AF-P46849-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 19:04:55,901 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpe5vw8txp /home/almalinux/data/cath-4.3-foldclassdb AF-P0A9Q9-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:05:10,702 | INFO | Finished easy-search in 14.801 seconds.
#
# search_file:  AF-P0A9Q9-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0A9Q9-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9Q9-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 19:04:54,755 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpjhpcqd0k /home/almalinux/data/cath-4.3-foldclassdb AF-P0AFQ2-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:05:11,103 | INFO | Finished easy-search in 16.348 seconds.
#
# search_file:  AF-P0AFQ2-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0AFQ2-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AFQ2-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9Q9-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0A9Q9-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9Q9-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AFQ2-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0AFQ2-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AFQ2-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9Q9-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0A9Q9-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9Q9-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AFQ2-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0AFQ2-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AFQ2-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9Q9-F1-model_v4.pdb.parsed': File exists
#
# AF-P0A9Q9-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P0A9S1-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmps50q1gvh /home/almalinux/data/cath-4.3-foldclassdb AF-P0A9S1-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AFQ2-F1-model_v4.pdb.parsed': File exists
#
# AF-P0AFQ2-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# 2024-12-25 19:05:11,463 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpdkxoy2g3 /home/almalinux/data/cath-4.3-foldclassdb AF-P75992-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:05:23,559 | INFO | Finished easy-search in 12.095 seconds.
#
# search_file:  AF-P75992-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P75992-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P75992-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P75992-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P75992-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P75992-F1-model_v4.pdb_search.tsv /analysis_outputs/
# File Name: AF-P16690-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp64skzpyl /home/almalinux/data/cath-4.3-foldclassdb AF-P16690-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P75992-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P75992-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P75992-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 19:05:12,828 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpubtjc1d2 /home/almalinux/data/cath-4.3-foldclassdb AF-P46849-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:05:29,728 | INFO | Finished easy-search in 16.900 seconds.
#
# search_file:  AF-P46849-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P46849-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46849-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P75992-F1-model_v4.pdb.parsed': File exists
#
# AF-P75992-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46849-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P46849-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46849-F1-model_v4.pdb_search.tsv /analysis_outputs/
# File Name: AF-P76503-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpkmqx7ral /home/almalinux/data/cath-4.3-foldclassdb AF-P76503-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46849-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P46849-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46849-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46849-F1-model_v4.pdb.parsed': File exists
#
# AF-P46849-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P46850-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpu_pfpk2q /home/almalinux/data/cath-4.3-foldclassdb AF-P46850-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 19:05:31,231 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp64skzpyl /home/almalinux/data/cath-4.3-foldclassdb AF-P16690-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:05:41,754 | INFO | Finished easy-search in 10.523 seconds.
#
# search_file:  AF-P16690-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P16690-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P16690-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 19:05:23,316 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmps50q1gvh /home/almalinux/data/cath-4.3-foldclassdb AF-P0A9S1-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:05:42,868 | INFO | Finished easy-search in 19.552 seconds.
#
# search_file:  AF-P0A9S1-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0A9S1-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9S1-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P16690-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P16690-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P16690-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9S1-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0A9S1-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9S1-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P16690-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P16690-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P16690-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9S1-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0A9S1-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0A9S1-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P16690-F1-model_v4.pdb.parsed': File exists
#
# AF-P16690-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0A9S1-F1-model_v4.pdb.parsed': File exists
#
# AF-P0A9S1-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P0AA60-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmphoza1wbd /home/almalinux/data/cath-4.3-foldclassdb AF-P0AA60-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 19:05:40,862 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpkmqx7ral /home/almalinux/data/cath-4.3-foldclassdb AF-P76503-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:06:04,888 | INFO | Finished easy-search in 24.026 seconds.
#
# search_file:  AF-P76503-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P76503-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P76503-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 19:05:43,806 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpu_pfpk2q /home/almalinux/data/cath-4.3-foldclassdb AF-P46850-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:06:05,613 | INFO | Finished easy-search in 21.808 seconds.
#
# search_file:  AF-P46850-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P46850-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46850-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P76503-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P76503-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P76503-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# 2024-12-25 19:05:57,908 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmphoza1wbd /home/almalinux/data/cath-4.3-foldclassdb AF-P0AA60-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:06:08,421 | INFO | Finished easy-search in 10.512 seconds.
#
# search_file:  AF-P0AA60-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0AA60-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AA60-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46850-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P46850-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46850-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P76503-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P76503-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P76503-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AA60-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0AA60-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AA60-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46850-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P46850-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P46850-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P76503-F1-model_v4.pdb.parsed': File exists
#
# AF-P76503-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AA60-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0AA60-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AA60-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P46850-F1-model_v4.pdb.parsed': File exists
#
# AF-P46850-F1-model_v4.pdb.parsed local file has been deleted.
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AA60-F1-model_v4.pdb.parsed': File exists
#
# AF-P0AA60-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P0ABA6-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpmk93ydqx /home/almalinux/data/cath-4.3-foldclassdb AF-P0ABA6-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 19:06:21,575 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmpmk93ydqx /home/almalinux/data/cath-4.3-foldclassdb AF-P0ABA6-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:06:30,882 | INFO | Finished easy-search in 9.307 seconds.
#
# search_file:  AF-P0ABA6-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0ABA6-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0ABA6-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0ABA6-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0ABA6-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0ABA6-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0ABA6-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0ABA6-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0ABA6-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0ABA6-F1-model_v4.pdb.parsed': File exists
#
# AF-P0ABA6-F1-model_v4.pdb.parsed local file has been deleted.
# File Name: AF-P0AC88-F1-model_v4.pdb
# STEP 1: RUNNING MERIZO: python3 /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp1j252wub /home/almalinux/data/cath-4.3-foldclassdb AF-P0AC88-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
# Output:
#
# Error:
# 2024-12-25 19:06:43,041 | INFO | Starting easy-search with command:
#
# /home/almalinux/merizo_search/merizo_search/merizo.py easy-search /tmp/tmp1j252wub /home/almalinux/data/cath-4.3-foldclassdb AF-P0AC88-F1-model_v4.pdb tmp --iterate --output_headers -d cpu --threads 2
#
# 2024-12-25 19:06:53,824 | INFO | Finished easy-search in 10.783 seconds.
#
# search_file:  AF-P0AC88-F1-model_v4.pdb_search.tsv
# STEP 2: RUNNING PARSER: python3 ./results_parser.py AF-P0AC88-F1-model_v4.pdb_search.tsv
# Output:
#
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AC88-F1-model_v4.pdb_segment.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AC88-F1-model_v4.pdb_segment.tsv': File exists
#
# AF-P0AC88-F1-model_v4.pdb_segment.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AC88-F1-model_v4.pdb_search.tsv /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AC88-F1-model_v4.pdb_search.tsv': File exists
#
# AF-P0AC88-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P0AC88-F1-model_v4.pdb.parsed /analysis_outputs/
# Output:
#
# Error:
# put: `/analysis_outputs/AF-P0AC88-F1-model_v4.pdb.parsed': File exists
#
# AF-P0AC88-F1-model_v4.pdb.parsed local file has been deleted.
# +----------+--------------------+
# |mean_plddt|    cath_counts_dict|
# +----------+--------------------+
# |   95.1058|{6.10.140.1350 ->...|
# |   95.7457|  {3.40.50.620 -> 1}|
# |   97.7731|{3.40.50.720 -> 1...|
# |  98.40875|{3.40.50.1970 -> ...|
# |       0.0|                  {}|
# |   90.7456|{1.10.287.1060 ->...|
# |   97.2253|{3.90.25.10 -> 1,...|
# |       0.0|                  {}|
# |   93.1894|  {3.40.50.300 -> 1}|
# |       0.0|                  {}|
# |  93.13824|{2.30.30.280 -> 1...|
# |   97.6179|{3.30.360.20 -> 1...|
# |   93.2427|{UNASSIGNED -> 1,...|
# |       0.0|                  {}|
# |   96.0342|   {3.40.47.10 -> 2}|
# |   92.0031|  {1.20.950.20 -> 1}|
# |   93.2138|    {1.10.8.50 -> 1}|
# +----------+--------------------+
#
# +-----------------+------------------+
# |             mean|           std_dev|
# +-----------------+------------------+
# |72.55550474279067|41.539901793132884|
# +-----------------+------------------+
#
# +-------------+-----------+
# |           id|total_count|
# +-------------+-----------+
# |  3.40.50.620|          2|
# |6.10.140.1350|          1|
# |  3.90.220.20|          2|
# | 3.40.50.1970|          1|
# |  3.30.360.10|          1|
# |1.10.287.1060|          1|
# |  3.40.50.720|          2|
# | 3.40.1380.10|          1|
# | 1.20.1090.10|          1|
# |   3.90.25.10|          1|
# | 3.30.110.140|          1|
# |  2.30.30.280|          1|
# |  3.40.50.300|          1|
# |  3.30.360.20|          1|
# |   2.40.30.10|          1|
# |   UNASSIGNED|          1|
# | 3.30.70.1560|          1|
# |  1.20.950.20|          1|
# |   3.40.47.10|          2|
# |    1.10.8.50|          1|
# +-------------+-----------+
#
# Done with the pipeline using collect in 197.14 seconds
# (DataFrame[mean: double, std_dev: double],
#  DataFrame[id: string, total_count: bigint])

# %%
def combine_parsed_dict_and_mean(analysis_output1, analysis_output2):
    cath_counts_dict1, mean_plddt1 = analysis_output1
    cath_counts_dict2, mean_plddt2 = analysis_output2

    for key in cath_counts_dict2:
        if key in cath_counts_dict1:
            cath_counts_dict1[key] +=cath_counts_dict2[key]
        else:
            cath_counts_dict1[key] = cath_counts_dict2[key]

    mean_plddt = (mean_plddt1 + mean_plddt2) / 2.0

    return cath_counts_dict1, mean_plddt

analysis_output1 = ({'3.40.710.10': 1}, 98.4244)
analysis_output2 = ({'3.40.710.10': 3, '2.30.810.20': 2}, 88.4244)

combine_parsed_dict_and_mean(analysis_output1, analysis_output2)

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, FloatType, MapType, StringType, IntegerType
import time
import random
from typing import Tuple, Dict
from statistics import mean, stdev

def generate_test_data(n: int) -> list[Tuple[float, Dict[str, int]]]:
    """Generate sample data for testing"""
    return [
        (
            random.uniform(1, 100),  # float value
            {f"id_{random.randint(1, 10)}": random.randint(1, 100) for _ in range(5)}  # count dict
        )
        for _ in range(n)
    ]

def benchmark_dataframe_approach(spark, data):
    """Benchmark DataFrame approach"""
    
    # Define schema
    schema = StructType([
        StructField("float_value", FloatType(), False),
        StructField("count_dict", MapType(StringType(), IntegerType()), False)
    ])
    
    # Create DataFrame
    df = spark.createDataFrame(data, schema)
    start_time = time.time()
    # Calculate statistics
    stats = df.select(
        F.mean("float_value").alias("mean"),
        F.stddev("float_value").alias("std_dev")
    ).first()
    
    # Combine dictionaries
    counts_df = df.select(
        F.explode("count_dict").alias("id", "count")
    ).groupBy(
        "id"
    ).agg(
        F.sum("count").alias("total_count")
    )
    
    combined_counts = dict(counts_df.collect())
    
    end_time = time.time()
    return end_time - start_time, stats, combined_counts

def benchmark_reduce_approach(spark, data):
    """Benchmark reduce approach"""
    start_time = time.time()
    
    rdd = spark.sparkContext.parallelize(data)
    
    # First reduction for float values
    float_values = rdd.map(lambda x: x[0]).collect()
    float_stats = {
        'mean': mean(float_values),
        'std_dev': stdev(float_values) if len(float_values) > 1 else 0.0
    }
    
    # Second reduction for dictionaries
    combined_counts = rdd.map(lambda x: x[1]) \
        .reduce(lambda acc, curr: {
            k: acc.get(k, 0) + curr.get(k, 0) 
            for k in set(acc) | set(curr)
        })
    
    end_time = time.time()
    return end_time - start_time, float_stats, combined_counts

def run_benchmark(sizes=[1000, 10000, 100000]):
    """Run benchmark with different data sizes"""
    spark = SparkSession.builder \
        .appName("BenchmarkTest") \
        .getOrCreate()
    
    results = []
    
    for size in sizes:
        print(f"\nBenchmarking with {size} records:")
        data = generate_test_data(size)
        
        # Warm up Spark
        spark.sparkContext.parallelize([1]).collect()
        
        # Run DataFrame benchmark
        df_time, df_stats, df_counts = benchmark_dataframe_approach(spark, data)
        print(f"DataFrame approach took: {df_time:.2f} seconds")
        print(f"DataFrame stats: Mean={df_stats['mean']:.2f}, StdDev={df_stats['std_dev']:.2f}")
        
        # Run Reduce benchmark
        reduce_time, reduce_stats, reduce_counts = benchmark_reduce_approach(spark, data)
        print(f"Reduce approach took: {reduce_time:.2f} seconds")
        print(f"Reduce stats: Mean={reduce_stats['mean']:.2f}, StdDev={reduce_stats['std_dev']:.2f}")
        
        results.append({
            'size': size,
            'dataframe_time': df_time,
            'reduce_time': reduce_time,
            'df_stats': df_stats,
            'reduce_stats': reduce_stats
        })
    
    return results

# %%
def benchmark_dataframe_approach(spark, data):

    # Define schema
    schema = StructType([
        StructField("float_value", FloatType(), False),
        StructField("count_dict", MapType(StringType(), IntegerType()), False)
    ])
    
    # Start timing after DataFrame creation to be fair
    df = spark.createDataFrame(data, schema)
    
    start_time = time.time()
    stats = df.select(
        F.mean("float_value").alias("mean"),
        F.stddev("float_value").alias("std_dev")
    ).first()
    
    counts_df = df.select(
        F.explode("count_dict").alias("id", "count")
    ).groupBy("id").agg(F.sum("count").alias("total_count"))
    
    combined_counts = dict(counts_df.collect())
    end_time = time.time()
    
    return end_time - start_time, stats, combined_counts

def benchmark_reduce_approach(spark, data):
    rdd = spark.sparkContext.parallelize(data)
    
    start_time = time.time()
    
    # Initialize with first element
    first = data[0]
    initial = ([first[0]], first[1])
    
    def combine_fn(acc, curr):
        values, counts = acc
        values.append(curr[0])
        for k, v in curr[1].items():
            counts[k] = counts.get(k, 0) + v
        return values, counts
        
    values, counts = rdd.reduce(combine_fn)
    
    stats = {
        'mean': mean(values),
        'std_dev': stdev(values) if len(values) > 1 else 0.0
    }
    end_time = time.time()
    
    return end_time - start_time, stats, counts

# %%
if __name__ == "__main__":
    results = run_benchmark()
    
    # Print summary
    print("\nSummary:")
    print("Size\tDataFrame(s)\tReduce(s)\tDifference(%)")
    for r in results:
        diff_percent = ((r['reduce_time'] - r['dataframe_time']) / r['dataframe_time']) * 100
        print(f"{r['size']}\t{r['dataframe_time']:.2f}\t\t{r['reduce_time']:.2f}\t\t{diff_percent:.1f}%")
# Out:
# Output:
#
# AF-P05719-F1-model_v4.pdb_search.tsv local file has been deleted.
# STEP 3: UPLOADING ANALYSIS OUTPUT TO HDFS: hdfs dfs -put AF-P05719-F1-model_v4.pdb.parsed /analysis_outputs/
